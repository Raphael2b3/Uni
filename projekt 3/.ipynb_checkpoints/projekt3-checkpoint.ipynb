# %%
# !pip install scipy numpy ipywidgets matplotlib
# Out:
# Requirement already satisfied: scipy in c:\users\guita\documents\dev\github\csv analyse\.venv\lib\site-packages (1.16.1)
# Requirement already satisfied: numpy in c:\users\guita\documents\dev\github\csv analyse\.venv\lib\site-packages (2.3.2)
# Requirement already satisfied: ipywidgets in c:\users\guita\documents\dev\github\csv analyse\.venv\lib\site-packages (8.1.7)
# Requirement already satisfied: matplotlib in c:\users\guita\documents\dev\github\csv analyse\.venv\lib\site-packages (3.10.5)
# Requirement already satisfied: comm>=0.1.3 in c:\users\guita\documents\dev\github\csv analyse\.venv\lib\site-packages (from ipywidgets) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\guita\documents\dev\github\csv analyse\.venv\lib\site-packages (from ipywidgets) (9.4.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\guita\documents\dev\github\csv analyse\.venv\lib\site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\users\guita\documents\dev\github\csv analyse\.venv\lib\site-packages (from ipywidgets) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in c:\users\guita\documents\dev\github\csv analyse\.venv\lib\site-packages (from ipywidgets) (3.0.15)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\guita\documents\dev\github\csv analyse\.venv\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\guita\documents\dev\github\csv analyse\.venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\guita\documents\dev\github\csv analyse\.venv\lib\site-packages (from matplotlib) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\guita\documents\dev\github\csv analyse\.venv\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\guita\documents\dev\github\csv analyse\.venv\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\guita\documents\dev\github\csv analyse\.venv\lib\site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\guita\documents\dev\github\csv analyse\.venv\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\guita\documents\dev\github\csv analyse\.venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: colorama in c:\users\guita\documents\dev\github\csv analyse\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.4.6)
# Requirement already satisfied: decorator in c:\users\guita\documents\dev\github\csv analyse\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in c:\users\guita\documents\dev\github\csv analyse\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\guita\documents\dev\github\csv analyse\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\guita\documents\dev\github\csv analyse\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.1.7)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\guita\documents\dev\github\csv analyse\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\guita\documents\dev\github\csv analyse\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (2.19.2)
# Requirement already satisfied: stack_data in c:\users\guita\documents\dev\github\csv analyse\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: wcwidth in c:\users\guita\documents\dev\github\csv analyse\.venv\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\guita\documents\dev\github\csv analyse\.venv\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.4)
# Requirement already satisfied: six>=1.5 in c:\users\guita\documents\dev\github\csv analyse\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\guita\documents\dev\github\csv analyse\.venv\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\guita\documents\dev\github\csv analyse\.venv\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\guita\documents\dev\github\csv analyse\.venv\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (0.2.3)
# WARNING: Ignoring invalid distribution ~tarlette (C:\Users\guita\Documents\dev\GitHub\csv analyse\.venv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~tarlette (C:\Users\guita\Documents\dev\GitHub\csv analyse\.venv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~tarlette (C:\Users\guita\Documents\dev\GitHub\csv analyse\.venv\Lib\site-packages)

# %% [markdown]
# # Finde ein Programm um eine Floyd Rose Gitarre effizient zu stimmen
#
# ## Einleitung
# Es gibt ein Problem beim Stimmen von Floyd Rose Gitarren. Bei diesen Gitarren wird eine Saite zwischen dem Gitarren Kopf und einer bis zu einem gewissen Grad rotierbaren Brücke gespannt. Bei der Brücke halten unterhalb des Drehpunkts Federn dagegen, wenn man Saiten einspannt. Das Floyd Rose Tremolo hat einen Hebel den man ziehen oder drücken kann. Beim musizieren ändert das den Ton.
# ### Bilder des Floyd Rose Tremolos
# <img style="height:30rem;" src="assets/floydrose_back.jpg"></img>
# <figcaption>Fig. 1 - Hier sieht man die Federn, die eine Gegenkraft zu den gespannten Saiten leisten.</figcaption>
#
#
# #### Neutrale Lage
# Wenn die Gitarre in einer neutralen Position ist sieht es folgender maßen aus:
# <div style="display:flex; align-items: flex-end;">
#     <div style="padding:10px;">
#         <img style="width:35rem;" src="assets/floydrose_frontside_neutral.jpg"></img>
#         <figcaption>Fig. 2 - Vorderseite der Gitarre bei neutraler Position.</figcaption>
#     </div>
#     <div style="padding:10px;">
#         <img style="width:35rem;" src="assets/floydrose_backside_neutral.jpg"></img>
#         <figcaption>Fig. 3 - Rückseite der Gitarre bei neutraler Position.</figcaption>
#     </div>
# </div>
#
# #### Saiten gestresst
# Wenn der Musiker den Ton der Saiten erhöhen möchte, kann er den Tremolo-Hebel anziehen, sodass die Saiten unter einer erhöhten Spannung stehen.
# <div style="display:flex; align-items: flex-end;">
#     <div style="padding:10px;">
#         <img style="width:35rem;" src="assets/floydrose_frontside_strings_stressed.jpg"></img>
#         <figcaption>Fig. 4 - Vorderseite der Gitarre bei gespannten Saiten.</figcaption>
#     </div>
#     <div style="padding:10px;">
#         <img style="width:35rem;" src="assets/floydrose_backside_strings_stressed.jpg"></img>
#         <figcaption>Fig. 5 - Rückseite der Gitarre bei gespannten Saiten.</figcaption>
#     </div>
# </div>
#
# #### Saiten entspannter
# Wenn der Musiker den Ton der Saiten verringern möchte, kann er den Tremolo-Hebel zur Gitarre drücken, sodass die Saiten unter einer niedrigeren Spannung stehen.
# <div style="display:flex; align-items: flex-end;">
#     <div style="padding:10px;">
#         <img style="width:35rem;" src="assets/floydrose_frontside_strings_released.jpg"></img>
#         <figcaption>Fig. 6 - Vorderseite der Gitarre bei entspannten Saiten.</figcaption>
#     </div>
#     <div style="padding:10px;">
#         <img style="width:35rem;" src="assets/floydrose_backside_strings_released.jpg"></img>
#         <figcaption>Fig. 7 - Rückseite der Gitarre bei entspannten Saiten.</figcaption>
#     </div>
# </div>

# %% [markdown]
# ## Problem
#
# Auch wenn diese Architektur einzigartige Klangwelten ermöglicht, erschwert es jedoch das Stimmen der Gitarre erheblich. Beim Stimmen erhöht oder verringert man die Spannung einer Saite, in dem man die Länge der Saite Verändert. Demnach erhöht oder verringert sich die Auslenkung der Federn, da zum Beispiel bei geringerer Spannung der Saiten auch eine geringere Kraft auf die Federn wirkt. Das Resultat davon ist, dass sich der Winkel des Floyd-Rose-Tremolos verändert. Das führt dazu, dass die anderen Saiten verstimmt werden, wenn man eine Saite stimmt.

# %% [markdown]
# ## Ziel
#
# In dieser Arbeit soll ein Weg gefunden werden, alle Saiten in die richtige Stimmung zu bringen, wobei jede Saite nur einmal gestimmt werden muss.
#
# ## Methodik
# Zunächst stellen wir ein mathematisches Modell auf, welches das Verhalten der Saiten beschreiben soll. Anschließend überprüfen wir das Modell mit einem Experiment.
# Dann werden die gewonnenen Erkenntnisse genutzt, um das Ziel in ein mathematisches Problem zu überführen.
# Zum Schluss wird die mathematische Lösung als Programm umgesetzt.

# %% [markdown]
# ## Mathematisches Modell
#
# Da es um das Stimmen der Saite geht, müssen wir zunächst verstehen welche Faktoren einfluss auf die Frequenz der Saite haben. Denn Stimmen heißt, Saiten in der richtigen Frequenz schwingen zu lassen.
# Die Frequenz einer Saite wird bestimmt durch
# $$
#     f = \frac{1}{2L_S} \sqrt{\frac{T}{\mu}},
# $$
#
# wobei $f$ die Frequenz, $L_S$ die Länge, $T$ die Spannung und $\mu$ die lineare Dichte der Saite ist [3].
#
# $\mu$ ist konstant und Saiten abhängig.
#
# Die Spannung $T$ ist proportional zur Kraft, die an der Saite zieht:
# $$
#     T = \frac{F}{A}
# $$
#
# wobei $F$ die Kraft ist und $A$ die Querschnittsfläche der Saite [4].
#
# Die Querschnittsfläche $A$ ist konstant und Saiten abhängig.
#
# Die Kraft $F$ ist die Kraft, mit der die Federn an der Brücke ziehen.
#
# Die Federkraft ist proportional zu Auslenkung der Federn [5].
#
# $$
#     F = L_F \cdot k
# $$
#
# $k$ ist die Federkonstante und $L_F$ die Auslenkung der Federn.
# $k$ ist konstant und Feder abhängig.
#
# Kombinieren wir nun also diese Gleichungen erhalten wir die Frequenz der Saite in Abhängigkeit der Auslenkung der Federn.
#
# $$
#     f = \frac{1}{2L} \sqrt{\frac{L_F \cdot k}{\mu}}
# $$
#
# Da die Brücke rotiert, wenn man die Saiten verkürzt ist die Auslenkung der Federn nicht linear zur Verkürzung der Saiten.
#
# Um die Abhängigkeit zwischen Auslenkung der Feder und Länge der Saite zu bestimmen, betrachten wir die Gitarre als Kombination von Punkten.
#
# <img src="assets/math_model.png" />
# <figcaption>Fig. 8 - Mathematisches Modell des Floyd-Rose-Tremolos.</figcaption>
#
# - Die Punkte $A$, $B$, $C$ sind konstant.
# - Der Winkel $\alpha = \sphericalangle{(\vec{u},\vec{v})} $ ist konstant.
# - Der Winkel $\beta = \sphericalangle{(\vec{v},\vec{e_x})}$ ist variabel.
# - $L_S,L_F$ sind Variable größen.
#
# Gesucht ist die Funktion $L_F(L_S)$. Sie beschreibt die Auslenkung der Feder in Abhängigkeit der Saiten Länge.
#
# Die Punkte $A$, $C$ und $D$ bilden ein Dreieck. Der Innenwinkel an Punkt $C$ ist:
# $$
# \varphi = \pi - \beta
# $$
#
# Das Dreieck hat die Saiten Längen $L_S$, $a_x$, $u$ wobei $A = (-a_x, a_y)$ und $u = |\vec{u}|$ .\
# Mit dem Kosinussatz erhalten wir:
#
# $$
#     L_S^2 = a_x^2 + u^2 - 2 a_x u \cos(\varphi)
# $$
#
# Umgestellt nach $\varphi$ erhalten wir:
#
# $$
#     \varphi = \cos^{-1}(\frac{a_x^2 + u^2 - L_S^2}{2 a_x u})
# $$
#
# Da $\varphi = \pi - \beta$ ist, erhalten wir:
#
# $$
#     \beta(L_S) = \pi - \cos^{-1}(\frac{a_x^2 + u^2 - L_S^2}{2 a_x u})
# $$
#
# $ v = |\vec v| $
#
# So Erhalten wir den Vektor $ \vec v = v \begin{pmatrix} \cos(\beta(L_S) - \alpha) \\ \sin(\beta(L_S) - \alpha) \end{pmatrix} $
#
# $ L_F = |\vec B - \vec v|$
#
# Daraus folgt:
#
# $$
#     L_F(L_S) = \sqrt{(a_x - v \cos(\beta(L_S) - \alpha))^2 + (a_y - v \sin(\beta(L_S) - \alpha))^2}
# $$
# Ausmultiplizieren:
#
# $$
#     L_F(L_S) = \sqrt{v^2 \cos^2(\beta(L_S) - \alpha) + v^2 \sin^2(\beta(L_S) - \alpha) +  a_x^2 + a_y^2 - 2v( \cos(\beta(L_S) - \alpha) a_x + \sin(\beta(L_S) - \alpha) a_y)}
# $$
# Vereinfachen, da $1 = sin^2(x)+cos^2(x)$
# $$
#     L_F(L_S) = \sqrt{v^2 + a_x^2 + a_y^2 - 2v( \cos(\beta(L_S) - \alpha) a_x + \sin(\beta(L_S) - \alpha) a_y)}
# $$
# Einsetzen von $\beta(L_S) = \pi - \cos^{-1}(\frac{a_x^2 + u^2 - L_S^2}{2 a_x u})$
# $$
#     L_F(L_S) = \sqrt{v^2 + a_x^2 + a_y^2 - 2v( \cos(\pi - \cos^{-1}(\frac{a_x^2 + u^2 - L_S^2}{2 a_x u}) - \alpha) a_x + \sin(\pi - \cos^{-1}(\frac{a_x^2 + u^2 - L_S^2}{2 a_x u}) - \alpha) a_y)}
# $$
# Vereinfachen, da
# 1. $cos(\pi+x) = -cos(x)$
# 2. $sin(\pi+x) = -sin(x)$
#
# $$
#     L_F(L_S) = \sqrt{v^2 + a_x^2 + a_y^2 - 2v( - \cos( - \cos^{-1}(\frac{a_x^2 + u^2 - L_S^2}{2 a_x u}) - \alpha) a_x - \sin( -\cos^{-1}(\frac{a_x^2 + u^2 - L_S^2}{2 a_x u}) - \alpha) a_y)}
# $$
# Vereinfachen, da
# 1. $sin(-x) = -sin(x)$
# 2. $cos(-x) = cos(x)$
# $$
#     L_F(L_S) = \sqrt{v^2 + a_x^2 + a_y^2 + 2v(\cos(\cos^{-1}(\frac{a_x^2 + u^2 - L_S^2}{2 a_x u}) + \alpha) a_x - \sin( \cos^{-1}(\frac{a_x^2 + u^2 - L_S^2}{2 a_x u}) + \alpha) a_y)}
# $$
#
# Kombinieren wir nun $L_F(L_S)$ und $f = \frac{1}{2L} \sqrt{\frac{L_F \cdot k}{\mu}}$ erhalten wir die Funktion $f(L_S): L_S \rightarrow f$, die die Auslenkung der Saite auf ihre Frequenz abbildet.
#
# $$
#     f(L_S) = \frac{1}{2L_S} \sqrt{\frac{\sqrt{v^2 + a_x^2 + a_y^2 - 2v( \cos(\pi - \cos^{-1}(\frac{a_x^2 + u^2 - L_S^2}{2 a_x u}) - \alpha) a_x + \sin(\pi - \cos^{-1}(\frac{a_x^2 + u^2 - L_S^2}{2 a_x u}) - \alpha) a_y)} \cdot k}{\mu}}
# $$
#
# Diese Funktion sieht so aus:
#
# <img src="assets/f(L_s).png">
# <figcaption>Fig. 9 - Funktion f(L_S)</figcaption>

# %% [markdown]
# ### Diskussion
# Die Korrelation zwischen Verlängerung der Saite und der Abnahme der Frequenz trifft zu, da wir eine negative Steigung sehen.
# Zu Beachten ist, dass nur der mittlere Teil der Funktion relevant ist da die Grenzfälle von $\beta$ durch Begrenzung des Rotationsspiels nicht erreicht werden können. Schätzungsweise bewegt sich Beta zwischen 5° bis 30°.

# %% [markdown]
# ## Experiment
#
# Um die Theorie zu überprüfen, wird ein Experiment durchgeführt, welches die Frequenzänderung der Saiten misst, wenn eine andere Saite verstimmt wird.
#
# Dazu wird zunächst jede Saite in eine Ausgangsposition gebracht. Eine standard Gitarren Stimmung ist EADGBE.
# Da eine Gitarre sich aufgrund von menschlichen Fehler nicht perfekt stimmen lässt, wird die Ausgangsfrequenz der Saiten gemessen und aufgezeichnet.
# Dann wird jede Saite um ein beliebiges Delta verstimmt. Das Delta wird so gewählt, dass die Saite sich deutlich hörbar verstimmt. Auch dieses Delta wird gemessen und aufgezeichnet.
#
# Jede Saite wird um 4 Schritte jeweils nach oben und nach unten verstimmt. Für jeden Schritt wird die Frequenz der anderen Saiten gemessen und aufgezeichnet.
#
# Das Ziel des Experiments ist zu beobachten, ob das System
# - hinreichend Linear ist (Nach der Theorie nicht zu erwarten)
# - elastisch ist
#
# Elastisch ist es, wenn die Frequenz einer Saite wieder in ihren Ausgangszustand zurückkehrt, wenn die Verstimmung aufgehoben wird.
# Dazu wird nach allen Verstimmungsschritten verglichen, ob die Frequenz der Saiten wieder in den Ausgangszustand zurückkehrt.
#
# Zum Messen der Frequenz, wird ein Python Programm sein, welches die Frequenz der Saiten mittels Fourier-Transformation berechnet. Die Visualisierungssoftware wird ebenfalls ein Python Programm sein, welches mit matplotlib.pyplot die Graphen anzeigt.
#
# Es werden 324 gelabelte Audio-Samples aufgenommen für das Experiment.
# Da Pro 6 Saiten der Einfluss auf alle 6 Saiten gemessen wird. Jede Saite wird dabei 4 Schritte nach oben und 4 Schritte nach unten Verstimmt. Hinzu kommt noch die Ausgangsposition.
# Wir erhalten also $ 324 = 6*6*(4*2+1)$.
#
# #### Frequenz Messgerät
#
# Die Audio-Samples werden mit Hilfe der Fourier Transformation in den Frequenzbereich transformiert. Die Frequenz mit der höchsten Amplitude wird als die Frequenz der Saite angenommen.
# Der Python Code um von einer Audio-Datei die Frequenz zu erhalten ist im folgenden definiert:

# %%
from scipy.fftpack import fft
from scipy.io import wavfile  # Import the wavfile API
import numpy as np


def get_samples(filepath):
    fs, data = wavfile.read(filepath)  # Load the data
    if len(data.shape) > 1:  # Check if stereo
        data = data.mean(axis=1)  # Convert to mono by averaging channels
    return data, fs


def fourier_transform(samples):
    spectrum = fft(samples)
    half = len(spectrum) // 2  # Take the first half of the spectrum
    return spectrum[:half]


def get_peak_frequency(spectrum, samplerate):
    # Get the magnitude of the spectrum
    magnitude = np.abs(spectrum)
    # Find the index of the peak frequency
    peak_idx = np.argmax(magnitude)
    # Map the index to a frequency value
    frequency = peak_idx * (samplerate / (2 * len(spectrum)))
    return frequency


def get_frequency_from_file(filepath):
    samples, samplerate = get_samples(filepath)
    spectrum = fourier_transform(samples)
    return get_peak_frequency(spectrum, samplerate)

# %% [markdown]
# #### Frequenz zu Cent Konvertierer
# Für Musiker ist es üblich die Frequenzdifferenz in Cent zu messen. Zwischen 2 Ganztönen liegen immer 100 Cent. Cent sind Logarithmisch.

# %%
def frequency_difference_to_cent(f1, f2):
    return 1200 * np.log2(f1 / f2)  # 1200 Cent entsprechen einem Halbton

# %% [markdown]
# #### Visualisierungssoftware
#
# Die Visualisierung zeigt die Frequenz der Saiten in Abhängigkeit von der Verstimmung.
# Die Daten zum Visualisieren werden wie folgt strukturiert:
#
# ```
# data = {
#     'E2': {                              // The first key represents the String that is detuned
#         'E2': [200Hz,220Hz,...,330Hz],                          // The second key represents the string on which the impact is measured
#                                          // The Value is a List of the length 8. on Index 0 is the measurement where the detuned string was tuned the lowest.
#         'D3': [340Hz,330Hz,...,300Hz]),
#         ...,
#         'E4': [...])
#     },
#     ...
#     'E4': {
#         'E2': [...]),
#         'A2': [...]),
#         ...,
#         'E4': [...])
#     }
# }
# ```
# Die Namen der Saiten sind wie folgt definiert:
# 1. E2
# 2. A2
# 3. D3
# 4. G3
# 5. B3
# 6. E4
#
# Das folgende Programm ermöglicht es uns die Daten zu visualisieren. Es gibt 6 Figuren mit jewails 6 Plots. Jede Figur zeigt wie sich alle Saiten verstimmen wenn ein sich eine andere Saite verändert. Pro Figur wird eine Checkbox für jede Saite erstellt, die es uns ermöglicht, die Daten für jede Saite einzeln anzuzeigen. Da interessant ist, ob die Verstimmung Logarithmisch ist, wird die änderung er Frequenz in Cent und in Hz dargestellt.
#
# Im Folgenden werden erstmal zufällige Messdaten generiert:

# %%
import matplotlib.pyplot as plt
from ipywidgets import HBox, VBox, interactive, Layout, Checkbox, fixed
import random

nStrings = 6
steps = 4
step_range = range(-steps, steps + 1)
strings = ["E2", "A2", "D3", "G3", "B3", "E4"]
# Verstimmung jeder anderen seite für jede Saite für alle Verstimmungsschritte
example_dataset = {  # Dummy Data
    string: {other_string: np.array([400 + (-_ * random.random() if other_string != string else _) for _ in step_range])
             for other_string in strings}
    for string in strings
}


def visualisation(df, string, label, **args):
    for other_string in strings:
        if other_string in args.keys() and args[other_string]:
            ## Lineare Regression
            x = df[string][string]
            y = df[string][other_string]
            #m,b = np.polyfit(x, y, 1)
            #plt.plot(x, m*x+b, label=f"Linear Fit {m}x+{b} {other_string}")
            plt.plot(df[string][string], df[string][other_string], label=other_string)

    plt.title("Impact on String when detuning String " + string)
    plt.xlabel(f"Detuning of String {string} in {label}")
    plt.ylabel(f"Frequency of other Strings in {label}")

    plt.legend()


def visualize_all(data, label): # Adds Checkboxes for every Sample
    widget_list = []

    for string in strings:
        checkboxes = {string: Checkbox(value=True, label=string, indent=False) for string in strings}
        widget = interactive(visualisation, df=fixed(data), string=fixed(string), label=fixed(label), **checkboxes)
        controls = HBox(widget.children[:-1])  # Horizontale Box für die Checkboxes
        output = widget.children[-1]
        w = VBox([controls, output], layout=Layout(margin="10px"))
        widget_list.append(w)
    row1 = HBox(widget_list[:3])
    row2 = HBox(widget_list[3:])
    output = VBox([row1, row2])
    display(output)


visualize_all(example_dataset, label="Hz")
# Out:
# VBox(children=(HBox(children=(VBox(children=(HBox(children=(Checkbox(value=True, description='E2', indent=Fals…

# %% [markdown]
# ### Durchführung
#
# Die Audio-Dateien sind im Ordner `audio` zu finden.
# Die Ordnerstruktur ist wie folgt:
#
#     ```
#     audio/<variable_saite>/<beeinflusste_saite>/<verstimmungsschritt>.wav
#
#     audio
#     ├── E2 # Ändernde Saite
#       ├── E2 # Beinflusste Saite
#         ├─── -4.wav
#         ├─── ...
#         ├─── 4.wav
#       ├─── ...
#       ├─── E4
#     ├── ...
#     ├── E4
#
# #### Setup
# Die Gitarre wird per Klinken Kabel an eine Audio Karte angeschlossen und mit einer Abtastrate von 44100 Hz aufgenommen. Das Bild Zeigt wie die Gitarre positioniert war, damit der Gitarrenhals sich nicht verzieht und dann den Ton beinflusst.
# <div style="border: 1px solid #ccc; padding:1px;">
#     <img src="assets/setup.jpg" width="500"/>
#     <figcaption>Fig. 10 - Setup der Aufnahme</figcaption>
# </div>
#
# Es wird die Digital Audio Workstation(DAW) "Cubase" verwendet um die Samples aufzunehmen. Die Aufnahme erfolgt in Mono. Die Aufnahme wird in 16 Bit und 44100 Hz aufgenommen.
# Es wird ein in der DAW integriertes Stimmgerät verwendet, um die Frequenz der Saiten für jeden Durchgang wieder in die Ausgangsposition zu bringen.
#
# <div style="border: 1px solid #ccc; padding:1px;">
#     <img src="assets/digital_setup.png" width="500"/>
#     <figcaption>Fig. 11 - Screenshot von Cubase mit Stimmgerät mit integriertem Frequenzmessgerät</figcaption>
# </div>
# Jeder Aufnahmeblock enthält den Klang aller Saiten der Gitarre. Also klingend E2, A2, D3, G3, B3 und E4. Die Saiten werden in der Reihenfolge E2, A2, D3, G3, B3 und E4 gespielt.
# Die Farbe der Aufnahme Blöcke ist eine Visualisierung dafür wie stark die Saiten verstimmt wurden und in welche Richtung. Je röter die Farbe, desto stärker die Verstimmung zu tieferen Frequenzen. Je blauer die Farbe, desto stärker die Verstimmung zu höheren Frequenzen.
#
# Jede Zeile widmet sich einer Saite und einer Verstimmungsrichtung. Von oben nach unten ist die Reihenfolge: E2 nach oben, E2 nach unten, A2 nach oben, A2 nach unten, ..., E4 nach oben, E4 nach unten.
#
#
# Anschließen werden die Einzelnen Audioblöcke so zu geschnitten, dass der Transient und das Verstummen der Saite verschwindet.
#
# <div style="border: 1px solid #ccc; padding:1px;">
# <img src="assets/cutted_audio.png" width="500"/>
#     <figcaption>Fig. 12 - Screenshot von Cubase mit zugeschnittenen Samples</figcaption>
# </div>
#
# Jede dieser kleinen Blöcke wird einzeln exportiert und in ihren entsprechenden Ordner verschoben.

# %% [markdown]
# ### Clean Up
# Da von dem oben geschriebenen Python-Programm in manchen Aufnahmen die Obertöne der Saite fälschlicher Weise als Ton erkannt wurden, werden die Samples noch einmal gefiltert.
# Die folgende Abbildung zeigt eine Konsolenausgabe von dem Problem.
# <div style="border: 1px solid #ccc; padding: 1px;">
#     <img src="assets/need_to_clean_data.png" width="500"/>
#     <figcaption>Fig. 13 – Screenshot der Zeigt das Obertöne erkannt werden statt Grundfrequenzen.</figcaption>
# </div>
# Der Screenshot Zeigt, dass nicht die Grundfrequenz als solche erkannt wird, sondern teilweise Obertöne als die Grundfrequenz erkannt werden. <br>
#     Deshalb wird für jede Saite ein Bandpass Filter erstellt, der die Obertöne reduziert.
#
# #### Banpass Filter:
# <div  style="
#     display: flex;
#     gap: 12px;
#   "
# >
#   <figure style="border: 1px solid #ccc; padding: 1px; margin: 0;">
#     <img src="assets/bandpass_e2.png" style="width:500px;">
#     <figcaption>Fig. 14 – Bandpass für E2</figcaption>
#   </figure>
#
#   <figure style="border: 1px solid #ccc; padding: 1px; margin: 0;">
#     <img src="assets/bandpass_a2.png" style="width:500px;">
#     <figcaption>Fig. 15 – Bandpass für A2</figcaption>
#   </figure>
# </div>
# <div  style="
#     display: flex;
#     gap: 12px;
#   "
# >
#   <figure style="border: 1px solid #ccc; padding: 1px; margin: 0;">
#     <img src="assets/bandpass_d3.png" style="width:500px;">
#     <figcaption>Fig. 16 – Bandpass für D3</figcaption>
#   </figure>
#
#   <figure style="border: 1px solid #ccc; padding: 1px; margin: 0;">
#     <img src="assets/bandpass_g3.png" style="width:500px;">
#     <figcaption>Fig. 17 – Bandpass für G3</figcaption>
#   </figure>
# </div><div  style="
#     display: flex;
#     gap: 12px;
#   "
# >
#   <figure style="border: 1px solid #ccc; padding: 1px; margin: 0;">
#     <img src="assets/bandpass_b3.png" style="width:500px;">
#     <figcaption>Fig. 18 – Bandpass für B3</figcaption>
#   </figure>
#
#   <figure style="border: 1px solid #ccc; padding: 1px; margin: 0;">
#     <img src="assets/bandpass_e4.png" style="width:500px;">
#     <figcaption>Fig. 19 – Bandpass für E4</figcaption>
#   </figure>
# </div>

# %% [markdown]
# ### Laden der Daten
# Im folgenden Script werden die gesamten Audio-Samples geladen um sie zu verarbeiten und zu visualisieren.

# %%
# Experiment
measured_data = {}
filenames = [f"{i}.wav" for i in step_range]
counter = 0
for changing_string in strings:
    for impacted_string in strings:
        #f0 = get_frequency_from_file(f"audio/{changing_string}/{impacted_string}/0.wav")

        for filename in filenames:
            frequency = get_frequency_from_file(f"audio/{changing_string}/{impacted_string}/{filename}")

            print(
                f"Saite: {changing_string}, Beeinflusste Saite: {impacted_string}, Verstimmungsschritt: {filename}, Frequenz: {frequency}")
            counter+=1
            if changing_string not in measured_data:
                measured_data[changing_string] = {}

            if impacted_string not in measured_data[changing_string]:
                measured_data[changing_string][impacted_string] = []

            measured_data[changing_string][impacted_string].append(frequency)
counter
# Out:
# C:\Users\guita\AppData\Local\Temp\ipykernel_39104\1026449666.py:7: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   fs, data = wavfile.read(filepath)  # Load the data
# Saite: E2, Beeinflusste Saite: E2, Verstimmungsschritt: -4.wav, Frequenz: 57.56155443488579
# Saite: E2, Beeinflusste Saite: E2, Verstimmungsschritt: -3.wav, Frequenz: 67.89055643973762
# Saite: E2, Beeinflusste Saite: E2, Verstimmungsschritt: -2.wav, Frequenz: 74.80436177036562
# Saite: E2, Beeinflusste Saite: E2, Verstimmungsschritt: -1.wav, Frequenz: 78.13278008298755
# Saite: E2, Beeinflusste Saite: E2, Verstimmungsschritt: 0.wav, Frequenz: 82.29854689564068
# Saite: E2, Beeinflusste Saite: E2, Verstimmungsschritt: 1.wav, Frequenz: 84.9931433230792
# Saite: E2, Beeinflusste Saite: E2, Verstimmungsschritt: 2.wav, Frequenz: 87.45281541913823
# Saite: E2, Beeinflusste Saite: E2, Verstimmungsschritt: 3.wav, Frequenz: 92.93188805334641
# Saite: E2, Beeinflusste Saite: E2, Verstimmungsschritt: 4.wav, Frequenz: 97.02425718679493
# Saite: E2, Beeinflusste Saite: A2, Verstimmungsschritt: -4.wav, Frequenz: 114.39652438637661
# Saite: E2, Beeinflusste Saite: A2, Verstimmungsschritt: -3.wav, Frequenz: 112.88238009315597
# Saite: E2, Beeinflusste Saite: A2, Verstimmungsschritt: -2.wav, Frequenz: 111.91015477538694
# Saite: E2, Beeinflusste Saite: A2, Verstimmungsschritt: -1.wav, Frequenz: 111.2360302980699
# Saite: E2, Beeinflusste Saite: A2, Verstimmungsschritt: 0.wav, Frequenz: 110.45549860205031
# Saite: E2, Beeinflusste Saite: A2, Verstimmungsschritt: 1.wav, Frequenz: 110.08433910135233
# Saite: E2, Beeinflusste Saite: A2, Verstimmungsschritt: 2.wav, Frequenz: 109.62357954545453
# Saite: E2, Beeinflusste Saite: A2, Verstimmungsschritt: 3.wav, Frequenz: 108.54113438937149
# Saite: E2, Beeinflusste Saite: A2, Verstimmungsschritt: 4.wav, Frequenz: 107.76268682161731
# Saite: E2, Beeinflusste Saite: D3, Verstimmungsschritt: -4.wav, Frequenz: 152.30757423294048
# Saite: E2, Beeinflusste Saite: D3, Verstimmungsschritt: -3.wav, Frequenz: 150.51958433253398
# Saite: E2, Beeinflusste Saite: D3, Verstimmungsschritt: -2.wav, Frequenz: 149.26464051208455
# Saite: E2, Beeinflusste Saite: D3, Verstimmungsschritt: -1.wav, Frequenz: 148.66658077814998
# Saite: E2, Beeinflusste Saite: D3, Verstimmungsschritt: 0.wav, Frequenz: 147.60843856907547
# Saite: E2, Beeinflusste Saite: D3, Verstimmungsschritt: 1.wav, Frequenz: 147.02649125968642
# Saite: E2, Beeinflusste Saite: D3, Verstimmungsschritt: 2.wav, Frequenz: 146.47011601001117
# Saite: E2, Beeinflusste Saite: D3, Verstimmungsschritt: 3.wav, Frequenz: 145.10846843498862
# Saite: E2, Beeinflusste Saite: D3, Verstimmungsschritt: 4.wav, Frequenz: 144.061103340043
# Saite: E2, Beeinflusste Saite: G3, Verstimmungsschritt: -4.wav, Frequenz: 209.0696269445703
# Saite: E2, Beeinflusste Saite: G3, Verstimmungsschritt: -3.wav, Frequenz: 205.11627906976744
# Saite: E2, Beeinflusste Saite: G3, Verstimmungsschritt: -2.wav, Frequenz: 202.02724488150892
# Saite: E2, Beeinflusste Saite: G3, Verstimmungsschritt: -1.wav, Frequenz: 200.6411449848732
# Saite: E2, Beeinflusste Saite: G3, Verstimmungsschritt: 0.wav, Frequenz: 199.2985059525817
# Saite: E2, Beeinflusste Saite: G3, Verstimmungsschritt: 1.wav, Frequenz: 197.67273414372994
# Saite: E2, Beeinflusste Saite: G3, Verstimmungsschritt: 2.wav, Frequenz: 196.76667812929847
# Saite: E2, Beeinflusste Saite: G3, Verstimmungsschritt: 3.wav, Frequenz: 194.21417792940557
# Saite: E2, Beeinflusste Saite: G3, Verstimmungsschritt: 4.wav, Frequenz: 191.93250581846394
# Saite: E2, Beeinflusste Saite: B3, Verstimmungsschritt: -4.wav, Frequenz: 255.99868566969238
# Saite: E2, Beeinflusste Saite: B3, Verstimmungsschritt: -3.wav, Frequenz: 253.23518362819985
# Saite: E2, Beeinflusste Saite: B3, Verstimmungsschritt: -2.wav, Frequenz: 251.14926016376958
# Saite: E2, Beeinflusste Saite: B3, Verstimmungsschritt: -1.wav, Frequenz: 250.0475805300471
# Saite: E2, Beeinflusste Saite: B3, Verstimmungsschritt: 0.wav, Frequenz: 248.76361443218505
# Saite: E2, Beeinflusste Saite: B3, Verstimmungsschritt: 1.wav, Frequenz: 248.0292640786135
# Saite: E2, Beeinflusste Saite: B3, Verstimmungsschritt: 2.wav, Frequenz: 247.06691109074245
# Saite: E2, Beeinflusste Saite: B3, Verstimmungsschritt: 3.wav, Frequenz: 245.0583911390976
# Saite: E2, Beeinflusste Saite: B3, Verstimmungsschritt: 4.wav, Frequenz: 243.48127389311117
# Saite: E2, Beeinflusste Saite: E4, Verstimmungsschritt: -4.wav, Frequenz: 336.3575894638819
# Saite: E2, Beeinflusste Saite: E4, Verstimmungsschritt: -3.wav, Frequenz: 334.1226155452216
# Saite: E2, Beeinflusste Saite: E4, Verstimmungsschritt: -2.wav, Frequenz: 332.7160493827161
# Saite: E2, Beeinflusste Saite: E4, Verstimmungsschritt: -1.wav, Frequenz: 331.91452235819645
# Saite: E2, Beeinflusste Saite: E4, Verstimmungsschritt: 0.wav, Frequenz: 331.08500059192613
# Saite: E2, Beeinflusste Saite: E4, Verstimmungsschritt: 1.wav, Frequenz: 330.42385347795863
# Saite: E2, Beeinflusste Saite: E4, Verstimmungsschritt: 2.wav, Frequenz: 329.87049157498956
# Saite: E2, Beeinflusste Saite: E4, Verstimmungsschritt: 3.wav, Frequenz: 328.53481219125734
# Saite: E2, Beeinflusste Saite: E4, Verstimmungsschritt: 4.wav, Frequenz: 327.5420046349942
# Saite: A2, Beeinflusste Saite: E2, Verstimmungsschritt: -4.wav, Frequenz: 86.48760330578511
# Saite: A2, Beeinflusste Saite: E2, Verstimmungsschritt: -3.wav, Frequenz: 84.83636246559023
# Saite: A2, Beeinflusste Saite: E2, Verstimmungsschritt: -2.wav, Frequenz: 83.91514752866003
# Saite: A2, Beeinflusste Saite: E2, Verstimmungsschritt: -1.wav, Frequenz: 83.10727654992053
# Saite: A2, Beeinflusste Saite: E2, Verstimmungsschritt: 0.wav, Frequenz: 82.38878672874526
# Saite: A2, Beeinflusste Saite: E2, Verstimmungsschritt: 1.wav, Frequenz: 81.98789256960237
# Saite: A2, Beeinflusste Saite: E2, Verstimmungsschritt: 2.wav, Frequenz: 81.20257785961459
# Saite: A2, Beeinflusste Saite: E2, Verstimmungsschritt: 3.wav, Frequenz: 80.25881696947167
# Saite: A2, Beeinflusste Saite: E2, Verstimmungsschritt: 4.wav, Frequenz: 79.44068747600626
# Saite: A2, Beeinflusste Saite: A2, Verstimmungsschritt: -4.wav, Frequenz: 76.02844204337809
# Saite: A2, Beeinflusste Saite: A2, Verstimmungsschritt: -3.wav, Frequenz: 92.11650394292151
# Saite: A2, Beeinflusste Saite: A2, Verstimmungsschritt: -2.wav, Frequenz: 98.40889276373147
# Saite: A2, Beeinflusste Saite: A2, Verstimmungsschritt: -1.wav, Frequenz: 105.08548620901924
# Saite: A2, Beeinflusste Saite: A2, Verstimmungsschritt: 0.wav, Frequenz: 110.55906283474258
# Saite: A2, Beeinflusste Saite: A2, Verstimmungsschritt: 1.wav, Frequenz: 113.89756050463438
# Saite: A2, Beeinflusste Saite: A2, Verstimmungsschritt: 2.wav, Frequenz: 118.88914677474068
# Saite: A2, Beeinflusste Saite: A2, Verstimmungsschritt: 3.wav, Frequenz: 124.75010148163182
# Saite: A2, Beeinflusste Saite: A2, Verstimmungsschritt: 4.wav, Frequenz: 130.75088623912342
# Saite: A2, Beeinflusste Saite: D3, Verstimmungsschritt: -4.wav, Frequenz: 152.757793764988
# Saite: A2, Beeinflusste Saite: D3, Verstimmungsschritt: -3.wav, Frequenz: 150.7097791798107
# Saite: A2, Beeinflusste Saite: D3, Verstimmungsschritt: -2.wav, Frequenz: 149.76943688594397
# Saite: A2, Beeinflusste Saite: D3, Verstimmungsschritt: -1.wav, Frequenz: 148.66019667625713
# Saite: A2, Beeinflusste Saite: D3, Verstimmungsschritt: 0.wav, Frequenz: 147.80829111577907
# Saite: A2, Beeinflusste Saite: D3, Verstimmungsschritt: 1.wav, Frequenz: 147.0489051536414
# Saite: A2, Beeinflusste Saite: D3, Verstimmungsschritt: 2.wav, Frequenz: 145.86167978179768
# Saite: A2, Beeinflusste Saite: D3, Verstimmungsschritt: 3.wav, Frequenz: 144.82358573954036
# Saite: A2, Beeinflusste Saite: D3, Verstimmungsschritt: 4.wav, Frequenz: 143.43535574629252
# Saite: A2, Beeinflusste Saite: G3, Verstimmungsschritt: -4.wav, Frequenz: 210.3999285841814
# Saite: A2, Beeinflusste Saite: G3, Verstimmungsschritt: -3.wav, Frequenz: 205.93810444874276
# Saite: A2, Beeinflusste Saite: G3, Verstimmungsschritt: -2.wav, Frequenz: 203.57190875274503
# Saite: A2, Beeinflusste Saite: G3, Verstimmungsschritt: -1.wav, Frequenz: 200.43444841760518
# Saite: A2, Beeinflusste Saite: G3, Verstimmungsschritt: 0.wav, Frequenz: 199.31224209078405
# Saite: A2, Beeinflusste Saite: G3, Verstimmungsschritt: 1.wav, Frequenz: 197.70368448365332
# Saite: A2, Beeinflusste Saite: G3, Verstimmungsschritt: 2.wav, Frequenz: 195.82938493069176
# Saite: A2, Beeinflusste Saite: G3, Verstimmungsschritt: 3.wav, Frequenz: 193.2092004381161
# Saite: A2, Beeinflusste Saite: G3, Verstimmungsschritt: 4.wav, Frequenz: 190.5006296802849
# Saite: A2, Beeinflusste Saite: B3, Verstimmungsschritt: -4.wav, Frequenz: 256.9094456185986
# Saite: A2, Beeinflusste Saite: B3, Verstimmungsschritt: -3.wav, Frequenz: 253.727817469463
# Saite: A2, Beeinflusste Saite: B3, Verstimmungsschritt: -2.wav, Frequenz: 252.15090111842994
# Saite: A2, Beeinflusste Saite: B3, Verstimmungsschritt: -1.wav, Frequenz: 251.09553517739027
# Saite: A2, Beeinflusste Saite: B3, Verstimmungsschritt: 0.wav, Frequenz: 249.25763455373715
# Saite: A2, Beeinflusste Saite: B3, Verstimmungsschritt: 1.wav, Frequenz: 247.6391169935272
# Saite: A2, Beeinflusste Saite: B3, Verstimmungsschritt: 2.wav, Frequenz: 246.26874323697635
# Saite: A2, Beeinflusste Saite: B3, Verstimmungsschritt: 3.wav, Frequenz: 244.19817661153644
# Saite: A2, Beeinflusste Saite: B3, Verstimmungsschritt: 4.wav, Frequenz: 242.2441595217494
# Saite: A2, Beeinflusste Saite: E4, Verstimmungsschritt: -4.wav, Frequenz: 336.85380622837374
# Saite: A2, Beeinflusste Saite: E4, Verstimmungsschritt: -3.wav, Frequenz: 334.42188879082084
# Saite: A2, Beeinflusste Saite: E4, Verstimmungsschritt: -2.wav, Frequenz: 333.29254599372354
# Saite: A2, Beeinflusste Saite: E4, Verstimmungsschritt: -1.wav, Frequenz: 332.0234008969509
# Saite: A2, Beeinflusste Saite: E4, Verstimmungsschritt: 0.wav, Frequenz: 331.5251487290427
# Saite: A2, Beeinflusste Saite: E4, Verstimmungsschritt: 1.wav, Frequenz: 330.37974683544303
# Saite: A2, Beeinflusste Saite: E4, Verstimmungsschritt: 2.wav, Frequenz: 329.65901779969977
# Saite: A2, Beeinflusste Saite: E4, Verstimmungsschritt: 3.wav, Frequenz: 328.1896551724138
# Saite: A2, Beeinflusste Saite: E4, Verstimmungsschritt: 4.wav, Frequenz: 326.5438995652704
# Saite: D3, Beeinflusste Saite: E2, Verstimmungsschritt: -4.wav, Frequenz: 87.64519739127078
# Saite: D3, Beeinflusste Saite: E2, Verstimmungsschritt: -3.wav, Frequenz: 85.70811588986864
# Saite: D3, Beeinflusste Saite: E2, Verstimmungsschritt: -2.wav, Frequenz: 84.42804076578722
# Saite: D3, Beeinflusste Saite: E2, Verstimmungsschritt: -1.wav, Frequenz: 83.25141584040546
# Saite: D3, Beeinflusste Saite: E2, Verstimmungsschritt: 0.wav, Frequenz: 82.4415493776899
# Saite: D3, Beeinflusste Saite: E2, Verstimmungsschritt: 1.wav, Frequenz: 82.06816098658445
# Saite: D3, Beeinflusste Saite: E2, Verstimmungsschritt: 2.wav, Frequenz: 81.49540084300575
# Saite: D3, Beeinflusste Saite: E2, Verstimmungsschritt: 3.wav, Frequenz: 80.81092241779797
# Saite: D3, Beeinflusste Saite: E2, Verstimmungsschritt: 4.wav, Frequenz: 79.23650594403013
# Saite: D3, Beeinflusste Saite: A2, Verstimmungsschritt: -4.wav, Frequenz: 115.99768530695987
# Saite: D3, Beeinflusste Saite: A2, Verstimmungsschritt: -3.wav, Frequenz: 114.52646701292961
# Saite: D3, Beeinflusste Saite: A2, Verstimmungsschritt: -2.wav, Frequenz: 112.85831999619694
# Saite: D3, Beeinflusste Saite: A2, Verstimmungsschritt: -1.wav, Frequenz: 111.76516695406804
# Saite: D3, Beeinflusste Saite: A2, Verstimmungsschritt: 0.wav, Frequenz: 110.55710306406685
# Saite: D3, Beeinflusste Saite: A2, Verstimmungsschritt: 1.wav, Frequenz: 110.13005637424588
# Saite: D3, Beeinflusste Saite: A2, Verstimmungsschritt: 2.wav, Frequenz: 109.58242888152634
# Saite: D3, Beeinflusste Saite: A2, Verstimmungsschritt: 3.wav, Frequenz: 108.69418132611638
# Saite: D3, Beeinflusste Saite: A2, Verstimmungsschritt: 4.wav, Frequenz: 107.10745635664266
# Saite: D3, Beeinflusste Saite: D3, Verstimmungsschritt: -4.wav, Frequenz: 85.4796618823396
# Saite: D3, Beeinflusste Saite: D3, Verstimmungsschritt: -3.wav, Frequenz: 108.22784810126582
# Saite: D3, Beeinflusste Saite: D3, Verstimmungsschritt: -2.wav, Frequenz: 126.54967074161925
# Saite: D3, Beeinflusste Saite: D3, Verstimmungsschritt: -1.wav, Frequenz: 141.21831381847517
# Saite: D3, Beeinflusste Saite: D3, Verstimmungsschritt: 0.wav, Frequenz: 147.7901981511887
# Saite: D3, Beeinflusste Saite: D3, Verstimmungsschritt: 1.wav, Frequenz: 152.71177130848042
# Saite: D3, Beeinflusste Saite: D3, Verstimmungsschritt: 2.wav, Frequenz: 158.3236122284795
# Saite: D3, Beeinflusste Saite: D3, Verstimmungsschritt: 3.wav, Frequenz: 167.59599463849247
# Saite: D3, Beeinflusste Saite: D3, Verstimmungsschritt: 4.wav, Frequenz: 180.80568720379145
# Saite: D3, Beeinflusste Saite: G3, Verstimmungsschritt: -4.wav, Frequenz: 211.53658536585365
# Saite: D3, Beeinflusste Saite: G3, Verstimmungsschritt: -3.wav, Frequenz: 207.98142347985743
# Saite: D3, Beeinflusste Saite: G3, Verstimmungsschritt: -2.wav, Frequenz: 204.62868769074262
# Saite: D3, Beeinflusste Saite: G3, Verstimmungsschritt: -1.wav, Frequenz: 199.80820547031354
# Saite: D3, Beeinflusste Saite: G3, Verstimmungsschritt: 0.wav, Frequenz: 198.9938340807175
# Saite: D3, Beeinflusste Saite: G3, Verstimmungsschritt: 1.wav, Frequenz: 197.56188195462335
# Saite: D3, Beeinflusste Saite: G3, Verstimmungsschritt: 2.wav, Frequenz: 196.315313925557
# Saite: D3, Beeinflusste Saite: G3, Verstimmungsschritt: 3.wav, Frequenz: 192.71134876002583
# Saite: D3, Beeinflusste Saite: G3, Verstimmungsschritt: 4.wav, Frequenz: 188.3582484455616
# Saite: D3, Beeinflusste Saite: B3, Verstimmungsschritt: -4.wav, Frequenz: 258.2026239252194
# Saite: D3, Beeinflusste Saite: B3, Verstimmungsschritt: -3.wav, Frequenz: 255.33633279244728
# Saite: D3, Beeinflusste Saite: B3, Verstimmungsschritt: -2.wav, Frequenz: 252.39549657920458
# Saite: D3, Beeinflusste Saite: B3, Verstimmungsschritt: -1.wav, Frequenz: 249.6693320507425
# Saite: D3, Beeinflusste Saite: B3, Verstimmungsschritt: 0.wav, Frequenz: 248.67877516228444
# Saite: D3, Beeinflusste Saite: B3, Verstimmungsschritt: 1.wav, Frequenz: 247.90845283999826
# Saite: D3, Beeinflusste Saite: B3, Verstimmungsschritt: 2.wav, Frequenz: 247.04247717348153
# Saite: D3, Beeinflusste Saite: B3, Verstimmungsschritt: 3.wav, Frequenz: 244.15481699621373
# Saite: D3, Beeinflusste Saite: B3, Verstimmungsschritt: 4.wav, Frequenz: 241.00444459817027
# Saite: D3, Beeinflusste Saite: E4, Verstimmungsschritt: -4.wav, Frequenz: 337.9781230404793
# Saite: D3, Beeinflusste Saite: E4, Verstimmungsschritt: -3.wav, Frequenz: 335.81702640911624
# Saite: D3, Beeinflusste Saite: E4, Verstimmungsschritt: -2.wav, Frequenz: 333.7342737323675
# Saite: D3, Beeinflusste Saite: E4, Verstimmungsschritt: -1.wav, Frequenz: 331.9561631368385
# Saite: D3, Beeinflusste Saite: E4, Verstimmungsschritt: 0.wav, Frequenz: 331.1024894924022
# Saite: D3, Beeinflusste Saite: E4, Verstimmungsschritt: 1.wav, Frequenz: 330.5025649246553
# Saite: D3, Beeinflusste Saite: E4, Verstimmungsschritt: 2.wav, Frequenz: 329.5258001306336
# Saite: D3, Beeinflusste Saite: E4, Verstimmungsschritt: 3.wav, Frequenz: 327.8369481022463
# Saite: D3, Beeinflusste Saite: E4, Verstimmungsschritt: 4.wav, Frequenz: 325.7716288436217
# Saite: G3, Beeinflusste Saite: E2, Verstimmungsschritt: -4.wav, Frequenz: 88.07529162248144
# Saite: G3, Beeinflusste Saite: E2, Verstimmungsschritt: -3.wav, Frequenz: 85.51031200423057
# Saite: G3, Beeinflusste Saite: E2, Verstimmungsschritt: -2.wav, Frequenz: 84.13176191283704
# Saite: G3, Beeinflusste Saite: E2, Verstimmungsschritt: -1.wav, Frequenz: 83.61623749503413
# Saite: G3, Beeinflusste Saite: E2, Verstimmungsschritt: 0.wav, Frequenz: 82.49938327440178
# Saite: G3, Beeinflusste Saite: E2, Verstimmungsschritt: 1.wav, Frequenz: 81.56709169439335
# Saite: G3, Beeinflusste Saite: E2, Verstimmungsschritt: 2.wav, Frequenz: 80.51363193768258
# Saite: G3, Beeinflusste Saite: E2, Verstimmungsschritt: 3.wav, Frequenz: 79.46764145600578
# Saite: G3, Beeinflusste Saite: E2, Verstimmungsschritt: 4.wav, Frequenz: 76.95814507183248
# Saite: G3, Beeinflusste Saite: A2, Verstimmungsschritt: -4.wav, Frequenz: 117.21773579155875
# Saite: G3, Beeinflusste Saite: A2, Verstimmungsschritt: -3.wav, Frequenz: 114.7627682079178
# Saite: G3, Beeinflusste Saite: A2, Verstimmungsschritt: -2.wav, Frequenz: 113.01303523144598
# Saite: G3, Beeinflusste Saite: A2, Verstimmungsschritt: -1.wav, Frequenz: 111.9759745035548
# Saite: G3, Beeinflusste Saite: A2, Verstimmungsschritt: 0.wav, Frequenz: 111.14410480349343
# Saite: G3, Beeinflusste Saite: A2, Verstimmungsschritt: 1.wav, Frequenz: 109.95539377616933
# Saite: G3, Beeinflusste Saite: A2, Verstimmungsschritt: 2.wav, Frequenz: 109.08611053612088
# Saite: G3, Beeinflusste Saite: A2, Verstimmungsschritt: 3.wav, Frequenz: 107.78004073319757
# Saite: G3, Beeinflusste Saite: A2, Verstimmungsschritt: 4.wav, Frequenz: 104.97500595096405
# Saite: G3, Beeinflusste Saite: D3, Verstimmungsschritt: -4.wav, Frequenz: 155.35289948722223
# Saite: G3, Beeinflusste Saite: D3, Verstimmungsschritt: -3.wav, Frequenz: 152.08860759493672
# Saite: G3, Beeinflusste Saite: D3, Verstimmungsschritt: -2.wav, Frequenz: 150.54450045139933
# Saite: G3, Beeinflusste Saite: D3, Verstimmungsschritt: -1.wav, Frequenz: 149.48690473737352
# Saite: G3, Beeinflusste Saite: D3, Verstimmungsschritt: 0.wav, Frequenz: 147.7958236658933
# Saite: G3, Beeinflusste Saite: D3, Verstimmungsschritt: 1.wav, Frequenz: 146.2660485021398
# Saite: G3, Beeinflusste Saite: D3, Verstimmungsschritt: 2.wav, Frequenz: 145.0540802324643
# Saite: G3, Beeinflusste Saite: D3, Verstimmungsschritt: 3.wav, Frequenz: 143.80846134042736
# Saite: G3, Beeinflusste Saite: D3, Verstimmungsschritt: 4.wav, Frequenz: 140.62620382656337
# Saite: G3, Beeinflusste Saite: G3, Verstimmungsschritt: -4.wav, Frequenz: 119.21583772027887
# Saite: G3, Beeinflusste Saite: G3, Verstimmungsschritt: -3.wav, Frequenz: 159.82382377218326
# Saite: G3, Beeinflusste Saite: G3, Verstimmungsschritt: -2.wav, Frequenz: 179.34605791128945
# Saite: G3, Beeinflusste Saite: G3, Verstimmungsschritt: -1.wav, Frequenz: 189.93246522161112
# Saite: G3, Beeinflusste Saite: G3, Verstimmungsschritt: 0.wav, Frequenz: 198.11946902654867
# Saite: G3, Beeinflusste Saite: G3, Verstimmungsschritt: 1.wav, Frequenz: 210.90099199300414
# Saite: G3, Beeinflusste Saite: G3, Verstimmungsschritt: 2.wav, Frequenz: 218.49988566201694
# Saite: G3, Beeinflusste Saite: G3, Verstimmungsschritt: 3.wav, Frequenz: 232.08785439271963
# Saite: G3, Beeinflusste Saite: G3, Verstimmungsschritt: 4.wav, Frequenz: 254.44531864673485
# Saite: G3, Beeinflusste Saite: B3, Verstimmungsschritt: -4.wav, Frequenz: 260.4463015647226
# Saite: G3, Beeinflusste Saite: B3, Verstimmungsschritt: -3.wav, Frequenz: 255.3247815419052
# Saite: G3, Beeinflusste Saite: B3, Verstimmungsschritt: -2.wav, Frequenz: 252.09977975203546
# Saite: G3, Beeinflusste Saite: B3, Verstimmungsschritt: -1.wav, Frequenz: 251.07627515208236
# Saite: G3, Beeinflusste Saite: B3, Verstimmungsschritt: 0.wav, Frequenz: 248.3360641844172
# Saite: G3, Beeinflusste Saite: B3, Verstimmungsschritt: 1.wav, Frequenz: 246.13350958360874
# Saite: G3, Beeinflusste Saite: B3, Verstimmungsschritt: 2.wav, Frequenz: 243.93386859524392
# Saite: G3, Beeinflusste Saite: B3, Verstimmungsschritt: 3.wav, Frequenz: 241.4340382233233
# Saite: G3, Beeinflusste Saite: B3, Verstimmungsschritt: 4.wav, Frequenz: 236.0685729773682
# Saite: G3, Beeinflusste Saite: E4, Verstimmungsschritt: -4.wav, Frequenz: 339.63327547186395
# Saite: G3, Beeinflusste Saite: E4, Verstimmungsschritt: -3.wav, Frequenz: 335.87144400432123
# Saite: G3, Beeinflusste Saite: E4, Verstimmungsschritt: -2.wav, Frequenz: 333.921859187509
# Saite: G3, Beeinflusste Saite: E4, Verstimmungsschritt: -1.wav, Frequenz: 332.1837847117902
# Saite: G3, Beeinflusste Saite: E4, Verstimmungsschritt: 0.wav, Frequenz: 330.9162497905646
# Saite: G3, Beeinflusste Saite: E4, Verstimmungsschritt: 1.wav, Frequenz: 329.3409639172612
# Saite: G3, Beeinflusste Saite: E4, Verstimmungsschritt: 2.wav, Frequenz: 327.8569539537481
# Saite: G3, Beeinflusste Saite: E4, Verstimmungsschritt: 3.wav, Frequenz: 325.85991430611756
# Saite: G3, Beeinflusste Saite: E4, Verstimmungsschritt: 4.wav, Frequenz: 322.19841793012523
# Saite: B3, Beeinflusste Saite: E2, Verstimmungsschritt: -4.wav, Frequenz: 85.81949072778612
# Saite: B3, Beeinflusste Saite: E2, Verstimmungsschritt: -3.wav, Frequenz: 84.81916764927608
# Saite: B3, Beeinflusste Saite: E2, Verstimmungsschritt: -2.wav, Frequenz: 83.8639829790439
# Saite: B3, Beeinflusste Saite: E2, Verstimmungsschritt: -1.wav, Frequenz: 83.0383923215357
# Saite: B3, Beeinflusste Saite: E2, Verstimmungsschritt: 0.wav, Frequenz: 82.77781394440466
# Saite: B3, Beeinflusste Saite: E2, Verstimmungsschritt: 1.wav, Frequenz: 82.21436699513352
# Saite: B3, Beeinflusste Saite: E2, Verstimmungsschritt: 2.wav, Frequenz: 80.67665858496804
# Saite: B3, Beeinflusste Saite: E2, Verstimmungsschritt: 3.wav, Frequenz: 80.31289434438453
# Saite: B3, Beeinflusste Saite: E2, Verstimmungsschritt: 4.wav, Frequenz: 77.75277615429573
# Saite: B3, Beeinflusste Saite: A2, Verstimmungsschritt: -4.wav, Frequenz: 114.67452543988905
# Saite: B3, Beeinflusste Saite: A2, Verstimmungsschritt: -3.wav, Frequenz: 113.79973351773455
# Saite: B3, Beeinflusste Saite: A2, Verstimmungsschritt: -2.wav, Frequenz: 112.9032258064516
# Saite: B3, Beeinflusste Saite: A2, Verstimmungsschritt: -1.wav, Frequenz: 111.82319892606772
# Saite: B3, Beeinflusste Saite: A2, Verstimmungsschritt: 0.wav, Frequenz: 111.31994035941301
# Saite: B3, Beeinflusste Saite: A2, Verstimmungsschritt: 1.wav, Frequenz: 110.7495145631068
# Saite: B3, Beeinflusste Saite: A2, Verstimmungsschritt: 2.wav, Frequenz: 109.05815021550201
# Saite: B3, Beeinflusste Saite: A2, Verstimmungsschritt: 3.wav, Frequenz: 108.87537239324728
# Saite: B3, Beeinflusste Saite: A2, Verstimmungsschritt: 4.wav, Frequenz: 106.0268623800141
# Saite: B3, Beeinflusste Saite: D3, Verstimmungsschritt: -4.wav, Frequenz: 152.47438140464885
# Saite: B3, Beeinflusste Saite: D3, Verstimmungsschritt: -3.wav, Frequenz: 151.46198830409355
# Saite: B3, Beeinflusste Saite: D3, Verstimmungsschritt: -2.wav, Frequenz: 150.46439628482972
# Saite: B3, Beeinflusste Saite: D3, Verstimmungsschritt: -1.wav, Frequenz: 149.24651994380827
# Saite: B3, Beeinflusste Saite: D3, Verstimmungsschritt: 0.wav, Frequenz: 148.43903396819164
# Saite: B3, Beeinflusste Saite: D3, Verstimmungsschritt: 1.wav, Frequenz: 147.6280048460116
# Saite: B3, Beeinflusste Saite: D3, Verstimmungsschritt: 2.wav, Frequenz: 146.00313479623824
# Saite: B3, Beeinflusste Saite: D3, Verstimmungsschritt: 3.wav, Frequenz: 145.27460967777654
# Saite: B3, Beeinflusste Saite: D3, Verstimmungsschritt: 4.wav, Frequenz: 141.917297781219
# Saite: B3, Beeinflusste Saite: G3, Verstimmungsschritt: -4.wav, Frequenz: 210.06472582588472
# Saite: B3, Beeinflusste Saite: G3, Verstimmungsschritt: -3.wav, Frequenz: 208.0863812258145
# Saite: B3, Beeinflusste Saite: G3, Verstimmungsschritt: -2.wav, Frequenz: 205.9464508094645
# Saite: B3, Beeinflusste Saite: G3, Verstimmungsschritt: -1.wav, Frequenz: 202.85024415248066
# Saite: B3, Beeinflusste Saite: G3, Verstimmungsschritt: 0.wav, Frequenz: 199.09865356390785
# Saite: B3, Beeinflusste Saite: G3, Verstimmungsschritt: 1.wav, Frequenz: 197.344499621244
# Saite: B3, Beeinflusste Saite: G3, Verstimmungsschritt: 2.wav, Frequenz: 194.75765244050805
# Saite: B3, Beeinflusste Saite: G3, Verstimmungsschritt: 3.wav, Frequenz: 193.59414681339942
# Saite: B3, Beeinflusste Saite: G3, Verstimmungsschritt: 4.wav, Frequenz: 187.13721215424445
# Saite: B3, Beeinflusste Saite: B3, Verstimmungsschritt: -4.wav, Frequenz: 142.2656084281977
# Saite: B3, Beeinflusste Saite: B3, Verstimmungsschritt: -3.wav, Frequenz: 171.89881214254288
# Saite: B3, Beeinflusste Saite: B3, Verstimmungsschritt: -2.wav, Frequenz: 198.28205214240177
# Saite: B3, Beeinflusste Saite: B3, Verstimmungsschritt: -1.wav, Frequenz: 226.05985037406484
# Saite: B3, Beeinflusste Saite: B3, Verstimmungsschritt: 0.wav, Frequenz: 248.5458674181281
# Saite: B3, Beeinflusste Saite: B3, Verstimmungsschritt: 1.wav, Frequenz: 262.1559003749657
# Saite: B3, Beeinflusste Saite: B3, Verstimmungsschritt: 2.wav, Frequenz: 282.36251661737975
# Saite: B3, Beeinflusste Saite: B3, Verstimmungsschritt: 3.wav, Frequenz: 293.0966200068283
# Saite: B3, Beeinflusste Saite: B3, Verstimmungsschritt: 4.wav, Frequenz: 337.19214465847506
# Saite: B3, Beeinflusste Saite: E4, Verstimmungsschritt: -4.wav, Frequenz: 336.5348144134381
# Saite: B3, Beeinflusste Saite: E4, Verstimmungsschritt: -3.wav, Frequenz: 334.98382332254886
# Saite: B3, Beeinflusste Saite: E4, Verstimmungsschritt: -2.wav, Frequenz: 333.7465415287799
# Saite: B3, Beeinflusste Saite: E4, Verstimmungsschritt: -1.wav, Frequenz: 332.36390667886553
# Saite: B3, Beeinflusste Saite: E4, Verstimmungsschritt: 0.wav, Frequenz: 331.0030808263864
# Saite: B3, Beeinflusste Saite: E4, Verstimmungsschritt: 1.wav, Frequenz: 330.050076619965
# Saite: B3, Beeinflusste Saite: E4, Verstimmungsschritt: 2.wav, Frequenz: 328.39194331452563
# Saite: B3, Beeinflusste Saite: E4, Verstimmungsschritt: 3.wav, Frequenz: 327.3976326906186
# Saite: B3, Beeinflusste Saite: E4, Verstimmungsschritt: 4.wav, Frequenz: 323.2716084392015
# Saite: E4, Beeinflusste Saite: E2, Verstimmungsschritt: -4.wav, Frequenz: 84.34378468368479
# Saite: E4, Beeinflusste Saite: E2, Verstimmungsschritt: -3.wav, Frequenz: 83.86417719201904
# Saite: E4, Beeinflusste Saite: E2, Verstimmungsschritt: -2.wav, Frequenz: 82.92960534455028
# Saite: E4, Beeinflusste Saite: E2, Verstimmungsschritt: -1.wav, Frequenz: 82.62578257094549
# Saite: E4, Beeinflusste Saite: E2, Verstimmungsschritt: 0.wav, Frequenz: 82.22747737505117
# Saite: E4, Beeinflusste Saite: E2, Verstimmungsschritt: 1.wav, Frequenz: 82.04202232435982
# Saite: E4, Beeinflusste Saite: E2, Verstimmungsschritt: 2.wav, Frequenz: 81.49787234042553
# Saite: E4, Beeinflusste Saite: E2, Verstimmungsschritt: 3.wav, Frequenz: 80.86727446473307
# Saite: E4, Beeinflusste Saite: E2, Verstimmungsschritt: 4.wav, Frequenz: 80.3399860756556
# Saite: E4, Beeinflusste Saite: A2, Verstimmungsschritt: -4.wav, Frequenz: 113.42447333034514
# Saite: E4, Beeinflusste Saite: A2, Verstimmungsschritt: -3.wav, Frequenz: 112.5568287560152
# Saite: E4, Beeinflusste Saite: A2, Verstimmungsschritt: -2.wav, Frequenz: 111.80680359435173
# Saite: E4, Beeinflusste Saite: A2, Verstimmungsschritt: -1.wav, Frequenz: 111.14805941542885
# Saite: E4, Beeinflusste Saite: A2, Verstimmungsschritt: 0.wav, Frequenz: 110.91350040420372
# Saite: E4, Beeinflusste Saite: A2, Verstimmungsschritt: 1.wav, Frequenz: 110.49989375265619
# Saite: E4, Beeinflusste Saite: A2, Verstimmungsschritt: 2.wav, Frequenz: 110.07053716766141
# Saite: E4, Beeinflusste Saite: A2, Verstimmungsschritt: 3.wav, Frequenz: 109.71929255232841
# Saite: E4, Beeinflusste Saite: A2, Verstimmungsschritt: 4.wav, Frequenz: 109.002687369364
# Saite: E4, Beeinflusste Saite: D3, Verstimmungsschritt: -4.wav, Frequenz: 151.0683181730211
# Saite: E4, Beeinflusste Saite: D3, Verstimmungsschritt: -3.wav, Frequenz: 150.08643353621204
# Saite: E4, Beeinflusste Saite: D3, Verstimmungsschritt: -2.wav, Frequenz: 149.06990730179797
# Saite: E4, Beeinflusste Saite: D3, Verstimmungsschritt: -1.wav, Frequenz: 148.42521943663587
# Saite: E4, Beeinflusste Saite: D3, Verstimmungsschritt: 0.wav, Frequenz: 147.88598359541396
# Saite: E4, Beeinflusste Saite: D3, Verstimmungsschritt: 1.wav, Frequenz: 147.42440358608116
# Saite: E4, Beeinflusste Saite: D3, Verstimmungsschritt: 2.wav, Frequenz: 147.02333703762503
# Saite: E4, Beeinflusste Saite: D3, Verstimmungsschritt: 3.wav, Frequenz: 146.20076912876277
# Saite: E4, Beeinflusste Saite: D3, Verstimmungsschritt: 4.wav, Frequenz: 145.62580425403073
# Saite: E4, Beeinflusste Saite: G3, Verstimmungsschritt: -4.wav, Frequenz: 207.14894460410267
# Saite: E4, Beeinflusste Saite: G3, Verstimmungsschritt: -3.wav, Frequenz: 204.96993170930588
# Saite: E4, Beeinflusste Saite: G3, Verstimmungsschritt: -2.wav, Frequenz: 202.625904820576
# Saite: E4, Beeinflusste Saite: G3, Verstimmungsschritt: -1.wav, Frequenz: 201.84520247356872
# Saite: E4, Beeinflusste Saite: G3, Verstimmungsschritt: 0.wav, Frequenz: 199.77709067376142
# Saite: E4, Beeinflusste Saite: G3, Verstimmungsschritt: 1.wav, Frequenz: 199.21944427987438
# Saite: E4, Beeinflusste Saite: G3, Verstimmungsschritt: 2.wav, Frequenz: 197.72438879959392
# Saite: E4, Beeinflusste Saite: G3, Verstimmungsschritt: 3.wav, Frequenz: 196.63371605495712
# Saite: E4, Beeinflusste Saite: G3, Verstimmungsschritt: 4.wav, Frequenz: 195.13661527471874
# Saite: E4, Beeinflusste Saite: B3, Verstimmungsschritt: -4.wav, Frequenz: 254.06684265577528
# Saite: E4, Beeinflusste Saite: B3, Verstimmungsschritt: -3.wav, Frequenz: 252.1090511547397
# Saite: E4, Beeinflusste Saite: B3, Verstimmungsschritt: -2.wav, Frequenz: 250.26663070091712
# Saite: E4, Beeinflusste Saite: B3, Verstimmungsschritt: -1.wav, Frequenz: 249.37736870600975
# Saite: E4, Beeinflusste Saite: B3, Verstimmungsschritt: 0.wav, Frequenz: 248.29145728643218
# Saite: E4, Beeinflusste Saite: B3, Verstimmungsschritt: 1.wav, Frequenz: 247.62576278139585
# Saite: E4, Beeinflusste Saite: B3, Verstimmungsschritt: 2.wav, Frequenz: 246.67808219178082
# Saite: E4, Beeinflusste Saite: B3, Verstimmungsschritt: 3.wav, Frequenz: 245.4220785505507
# Saite: E4, Beeinflusste Saite: B3, Verstimmungsschritt: 4.wav, Frequenz: 244.27276582211385
# Saite: E4, Beeinflusste Saite: E4, Verstimmungsschritt: -4.wav, Frequenz: 209.80184005661712
# Saite: E4, Beeinflusste Saite: E4, Verstimmungsschritt: -3.wav, Frequenz: 253.76835801438085
# Saite: E4, Beeinflusste Saite: E4, Verstimmungsschritt: -2.wav, Frequenz: 291.919521621057
# Saite: E4, Beeinflusste Saite: E4, Verstimmungsschritt: -1.wav, Frequenz: 315.13118958374434
# Saite: E4, Beeinflusste Saite: E4, Verstimmungsschritt: 0.wav, Frequenz: 330.6094909663393
# Saite: E4, Beeinflusste Saite: E4, Verstimmungsschritt: 1.wav, Frequenz: 343.49691511240337
# Saite: E4, Beeinflusste Saite: E4, Verstimmungsschritt: 2.wav, Frequenz: 357.963520120346
# Saite: E4, Beeinflusste Saite: E4, Verstimmungsschritt: 3.wav, Frequenz: 373.33415466929495
# Saite: E4, Beeinflusste Saite: E4, Verstimmungsschritt: 4.wav, Frequenz: 392.8650727031491
# 324

# %% [markdown]
# ### Aggregierung der Daten
# Gemessen haben wir die tatsächlichen Frequenzen und wie sie sich in Abhängigkeit jeder anderen Saite ändern. Jedoch interessiert uns vorallem das Maß dieser Änderung. Daher werden wir jeden Messwert zu seinem Ausgangswert vergleichen in Cent und Herz, sodass wir auch die Änderung der Frequenzen sehen.

# %%
cent_changes = {  # Dummy Data
    string: {other_string: np.array([float(0) for _ in step_range]) for other_string in strings}
    for string in strings
}
hz_changes = cent_changes.copy()

for changing_string in strings:
    for impacted_string in strings:
        inital_value = measured_data[changing_string][impacted_string][steps]
        for i in range(steps * 2 + 1):  # -4 bis 4
            cent_changes[changing_string][impacted_string][i] = frequency_difference_to_cent(
                measured_data[changing_string][impacted_string][i], inital_value)
            hz_changes[changing_string][impacted_string][i] = measured_data[changing_string][impacted_string][
                                                                  i] - inital_value

# %% [markdown]
# ## Visualisierung
# ### Frequenz in Abhängigkeit der Frequenz der Verstimmten Saite (Absolute Werte)

# %%
visualize_all(measured_data, label="Hz")
# Out:
# VBox(children=(HBox(children=(VBox(children=(HBox(children=(Checkbox(value=True, description='E2', indent=Fals…

# %% [markdown]
# ### Frequenz Änderung in Cent (Relative Werte)

# %%
visualize_all(cent_changes, label="Cent")
# Out:
# VBox(children=(HBox(children=(VBox(children=(HBox(children=(Checkbox(value=True, description='E2', indent=Fals…

# %% [markdown]
# ### Frequenz Änderung in Hz (Relative Werte)

# %%
visualize_all(hz_changes, label="Hz")
# Out:
# VBox(children=(HBox(children=(VBox(children=(HBox(children=(Checkbox(value=True, description='E2', indent=Fals…

# %% [markdown]
# ## Diskussion
# ### Elastizität und Linearität
# Es ist elastisch, weil Ausgangs- und Endfrequenzen gleich sind. Bei der Umsetzung des Experiments war auffällig, dass wenn man die Saite wieder in die Ausgangsposition gebracht hat. Alle anderen Saiten wieder in ihrer Ausgangsfrequenz schwangen.
#
# Das System ist nicht perfekt linear. Man erkennt eine leichte Krümmung die auch schon durch das erste mathematische Modell vorausgesagt wurde (Fig. 9).
# ### Neues mathematisches Modell
#
# Beim Stimmen der Gitarre sind in der Regel nur kleine Änderungen nötig. Deswegen gilt die Lokale Linearität und wir können das System als Linear annehmen.
#
# Nun können das System als ein lineares Gleichungssystem beschreiben. Die Frequenz der Saiten kann als Vektor dargestellt werden. Jede Dimension bezieht sich auf eine Saite. Die Verstimmungsfaktoren der Saiten kann als Matrix dargestellt werden.
#
# $$
# \vec{f_0} = \begin{pmatrix} {f_{E2}} \\ {f_{A2}} \\ {f_{D3}} \\ {f_{G3}} \\ {f_{B3}} \\ {f_{e4}} \end{pmatrix},
# C = \begin{bmatrix} {1} & { c_{12} } & {c_{13}} & {c_{14}} & {c_{15}} & {c_{16}} \\ {c_{21}} & {1} & {c_{23}} & {c_{24}} & {c_{25}} & {c_{26}} \\ {c_{31}} & {c_{32}} & {1} & {c_{34}} & {c_{35}} & {c_{36}} \\ {c_{41}} & {c_{42}} & {c_{43}} & {1} & {c_{45}} & {c_{46}} \\ {c_{51}} & {c_{52}} & {c_{53}} & {c_{54}} & {1} & {c_{56}} \\ {c_{61}} & {c_{62}} & {c_{63}} & {c_{64}} & {c_{65}} & {1} \end{bmatrix},
# \vec{g} = \begin{pmatrix} {\hat{f}_{E2}} \\ {\hat{f}_{A2}} \\ {\hat{f}_{D3}} \\ {\hat{f}_{G3}} \\ {\hat{f}_{B3}} \\ {\hat{f}_{e4}} \end{pmatrix}
# $$
# \
# $\vec{f_0}$ sind die Frequenzen der Saiten in der Ausgangsposition.\
# $C$ ist die Verstimmungsmatrix. Die Elemente $c_{ij}$ sind die Verstimmungsfaktoren der Saite $i$, wenn die Saite $j$ um 1 Hz verstimmt wird.\
# $\vec{g}$ sind die Frequenzen der Saiten nach der Verstimmung.\
# $\vec{g}$ wollen wir im allgemeinen als Zielfrequenzen erreichen.
#
# Der Vektor $\vec{\Delta} = \begin{pmatrix} {\Delta_{E2}} \\ {\Delta_{A2}} \\ {\Delta_{D3}} \\ {\Delta_{G3}} \\ {\Delta_{B3}} \\ {\Delta_{E4}} \end{pmatrix}$ gibt an wie viel wir jede Saite verstimmen in $Hz$. Um jetzt die effektive Verstimmung zu berechnen, müssen wir lediglich mit der Verstimmungsmatrix Multiplizieren
#
# $$
# \vec{\Delta} \cdot C = \vec{\Delta}_{effective}
# $$
#
# Wir wissen dass die effektive Verstimmung $\vec{\Delta}_{effective}$ so gewählt sein muss, dass am Ende unsere Ziel Frequenzen $\vec{g}$ erreicht werden.
#
# $$
#     \vec{g} = \vec{f_0} +  \vec{\Delta}_{effective} => \vec{\Delta}_{effective}  = \vec{g}-\vec{f_0}
# $$
# Um nun die Eingangsverstummung $\vec{\Delta}$ zu bestimmen muss lediglich das Inverse der Matrix $C$ gebildet werden
#
# $$
#     \vec{\Delta} \cdot C  = \vec{\Delta}_{effective}  => \vec{\Delta} = \vec{\Delta}_{effective} \cdot C^{-1}
# $$
#
# $$
# \vec{\Delta} = (\vec{g}-\vec{f_0}) \cdot C^{-1}
# $$
#
# $C^{-1}$ ist die Inverse der Verstimmungsmatrix.
#
# Man benötigt also Ausgansfrequenz $\vec{f_0}$, die Ziel Frequenz $\vec{g}$ und die Verstimmungsmatrix $C$.
#
# ### Programmierung
# Die Funktion wird mit numpy implementiert, da es eine viel Zahl von Algorithmen unteranderem Matrix-Multiplikation und Inverse-Bilden einer Matrix unterstützt.
#
# Zu programmieren ist $\Delta: \vec{f_0}, \vec{g}, C \rightarrow \Delta$. Am Ende erhalten wir einen Vektor der für jede Saite angibt um wieviel Hz diese Saite verstimmt werden muss.

# %%
def delta(f0, g, C):
    return (g - f0) @ np.linalg.inv(C)

# %% [markdown]
# ## Literatur
# [1]Gleich temperierte Stimmung: https://de.wikipedia.org/wiki/Gleichstufige_Stimmung \
# [2]Cent: https://de.wikipedia.org/wiki/Cent_(Musik) \
# [3]Vibration of a String: https://en.wikipedia.org/wiki/String_vibration \
# [4]Mechanische Spannung: https://de.wikipedia.org/wiki/Mechanische_Spannung \
# [5]Hookesches Gesetz: https://de.wikipedia.org/wiki/Hookesches_Gesetz
#
# ## TODO
# - Einfluss vom Radius u
# - reale Wertebereiche für das Modell Nutzen $\beta$ usw...
# - scipy peak detection
# - Annahmen
